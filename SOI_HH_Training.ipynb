# %% [markdown]
# #### Importing Modules

# %%
import os
# %matplotlib inline
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Conv2D, Dense, BatchNormalization, Dropout, MaxPooling2D, Flatten

# %% [markdown]
# #### Defining Train and Test Directory

# %%
train_dir = '/content/data/train/'
test_dir = '/content/data/test/'
classes = len(os.listdir('/content/data_aug/train/'))

# %% [markdown]
# #### Loading Training and Testing data

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=10,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=10,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

training_set.class_indices
# Out:
# Found 35000 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %% [markdown]
# #### Defining Model Architecture

# %%
emotor = tf.keras.models.Sequential()   

emotor.add(Conv2D(10, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48, 1)))
emotor.add(Conv2D(20, kernel_size=(3, 3), activation='relu', padding='same'))
emotor.add(BatchNormalization())
emotor.add(MaxPooling2D(2, 2))
emotor.add(Dropout(0.25))

emotor.add(Conv2D(40, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
emotor.add(Conv2D(80, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
emotor.add(BatchNormalization())
emotor.add(MaxPooling2D(pool_size=(2, 2)))
emotor.add(Dropout(0.25))

emotor.add(Conv2D(160, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.02)))
emotor.add(Conv2D(320, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.02)))
emotor.add(BatchNormalization())
emotor.add(MaxPooling2D(pool_size=(2, 2)))
emotor.add(Dropout(0.25))

emotor.add(Flatten())
emotor.add(Dense(1024, activation='relu'))
emotor.add(Dropout(0.5))

emotor.add(Dense(classes, activation='softmax'))

emotor.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

emotor.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 48, 48, 10)        100
#
#  conv2d_7 (Conv2D)           (None, 48, 48, 20)        1820
#
#  batch_normalization_3 (Batc  (None, 48, 48, 20)       80
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 24, 24, 20)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 20)        0
#
#  conv2d_8 (Conv2D)           (None, 24, 24, 40)        7240
#
#  conv2d_9 (Conv2D)           (None, 22, 22, 80)        28880
#
#  batch_normalization_4 (Batc  (None, 22, 22, 80)       320
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 11, 11, 80)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 11, 11, 80)        0
#
#  conv2d_10 (Conv2D)          (None, 11, 11, 160)       115360
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 320)       461120
#
#  batch_normalization_5 (Batc  (None, 11, 11, 320)      1280
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 320)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 5, 5, 320)         0
#
#  flatten_1 (Flatten)         (None, 8000)              0
#
#  dense_2 (Dense)             (None, 1024)              8193024
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 8,816,399
# Trainable params: 8,815,559
# Non-trainable params: 840
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# #### Defining Checkpoint saves, Early-Stopping and Learning rate decay

# %%
chk_path = 'emotor.h5'

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_accuracy')

earlystop = EarlyStopping(monitor='val_accuracy', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


callbacks = [checkpoint, reduce_lr]

# %% [markdown]
# #### Training the Model

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

emotor.fit(x=training_set,
                  validation_data=test_set,
                  epochs=70,
                  callbacks=callbacks,
                  steps_per_epoch=steps_per_epoch,
                  validation_steps=validation_steps)
# Out:
# Epoch 1/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 6.7774 - accuracy: 0.2508
# Epoch 1: val_loss improved from inf to 4.28522, saving model to emotor.h5
# 3500/3500 [==============================] - 47s 13ms/step - loss: 6.7766 - accuracy: 0.2509 - val_loss: 4.2852 - val_accuracy: 0.3045 - lr: 1.0000e-04
# Epoch 2/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 3.0163 - accuracy: 0.3417
# Epoch 2: val_loss improved from 4.28522 to 2.31480, saving model to emotor.h5
# 3500/3500 [==============================] - 45s 13ms/step - loss: 3.0155 - accuracy: 0.3417 - val_loss: 2.3148 - val_accuracy: 0.3796 - lr: 1.0000e-04
# Epoch 3/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 2.0675 - accuracy: 0.3958
# Epoch 3: val_loss improved from 2.31480 to 2.05579, saving model to emotor.h5
# 3500/3500 [==============================] - 45s 13ms/step - loss: 2.0673 - accuracy: 0.3959 - val_loss: 2.0558 - val_accuracy: 0.3662 - lr: 1.0000e-04
# Epoch 4/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 1.7784 - accuracy: 0.4472
# Epoch 4: val_loss improved from 2.05579 to 1.65555, saving model to emotor.h5
# 3500/3500 [==============================] - 46s 13ms/step - loss: 1.7781 - accuracy: 0.4474 - val_loss: 1.6556 - val_accuracy: 0.4798 - lr: 1.0000e-04
# Epoch 5/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 1.6349 - accuracy: 0.4778
# Epoch 5: val_loss improved from 1.65555 to 1.51696, saving model to emotor.h5
# 3500/3500 [==============================] - 45s 13ms/step - loss: 1.6351 - accuracy: 0.4777 - val_loss: 1.5170 - val_accuracy: 0.5132 - lr: 1.0000e-04
# Epoch 6/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 1.5502 - accuracy: 0.4979
# Epoch 6: val_loss did not improve from 1.51696
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.5502 - accuracy: 0.4979 - val_loss: 1.5278 - val_accuracy: 0.5059 - lr: 1.0000e-04
# Epoch 7/70
# 3500/3500 [==============================] - ETA: 0s - loss: 1.4915 - accuracy: 0.5154
# Epoch 7: val_loss improved from 1.51696 to 1.41181, saving model to emotor.h5
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.4915 - accuracy: 0.5154 - val_loss: 1.4118 - val_accuracy: 0.5385 - lr: 1.0000e-04
# Epoch 8/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 1.4461 - accuracy: 0.5277
# Epoch 8: val_loss did not improve from 1.41181
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.4461 - accuracy: 0.5277 - val_loss: 1.4677 - val_accuracy: 0.5077 - lr: 1.0000e-04
# Epoch 9/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 1.4031 - accuracy: 0.5414
# Epoch 9: val_loss improved from 1.41181 to 1.33166, saving model to emotor.h5
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.4030 - accuracy: 0.5414 - val_loss: 1.3317 - val_accuracy: 0.5600 - lr: 1.0000e-04
# Epoch 10/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 1.3704 - accuracy: 0.5519
# Epoch 10: val_loss improved from 1.33166 to 1.30607, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.3704 - accuracy: 0.5519 - val_loss: 1.3061 - val_accuracy: 0.5699 - lr: 1.0000e-04
# Epoch 11/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 1.3424 - accuracy: 0.5596
# Epoch 11: val_loss did not improve from 1.30607
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.3424 - accuracy: 0.5596 - val_loss: 1.4124 - val_accuracy: 0.5297 - lr: 1.0000e-04
# Epoch 12/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 1.3194 - accuracy: 0.5673
# Epoch 12: val_loss did not improve from 1.30607
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.3195 - accuracy: 0.5673 - val_loss: 1.3498 - val_accuracy: 0.5509 - lr: 1.0000e-04
# Epoch 13/70
# 3500/3500 [==============================] - ETA: 0s - loss: 1.3007 - accuracy: 0.5705
# Epoch 13: val_loss improved from 1.30607 to 1.30427, saving model to emotor.h5
# 3500/3500 [==============================] - 45s 13ms/step - loss: 1.3007 - accuracy: 0.5705 - val_loss: 1.3043 - val_accuracy: 0.5785 - lr: 1.0000e-04
# Epoch 14/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 1.2826 - accuracy: 0.5749
# Epoch 14: val_loss did not improve from 1.30427
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.2825 - accuracy: 0.5749 - val_loss: 1.3731 - val_accuracy: 0.5584 - lr: 1.0000e-04
# Epoch 15/70
# 3500/3500 [==============================] - ETA: 0s - loss: 1.2676 - accuracy: 0.5840
# Epoch 15: val_loss improved from 1.30427 to 1.25235, saving model to emotor.h5
# 3500/3500 [==============================] - 44s 12ms/step - loss: 1.2676 - accuracy: 0.5840 - val_loss: 1.2524 - val_accuracy: 0.5921 - lr: 1.0000e-04
# Epoch 16/70
# 3500/3500 [==============================] - ETA: 0s - loss: 1.2542 - accuracy: 0.5907
# Epoch 16: val_loss improved from 1.25235 to 1.24777, saving model to emotor.h5
# 3500/3500 [==============================] - 45s 13ms/step - loss: 1.2542 - accuracy: 0.5907 - val_loss: 1.2478 - val_accuracy: 0.5941 - lr: 1.0000e-04
# Epoch 17/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 1.2410 - accuracy: 0.5960
# Epoch 17: val_loss did not improve from 1.24777
# 3500/3500 [==============================] - 45s 13ms/step - loss: 1.2413 - accuracy: 0.5961 - val_loss: 1.2784 - val_accuracy: 0.5824 - lr: 1.0000e-04
# Epoch 18/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 1.2235 - accuracy: 0.6012
# Epoch 18: val_loss did not improve from 1.24777
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.2237 - accuracy: 0.6011 - val_loss: 1.2649 - val_accuracy: 0.5894 - lr: 1.0000e-04
# Epoch 19/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 1.2144 - accuracy: 0.6010
# Epoch 19: val_loss improved from 1.24777 to 1.21357, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.2143 - accuracy: 0.6011 - val_loss: 1.2136 - val_accuracy: 0.6042 - lr: 1.0000e-04
# Epoch 20/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 1.2001 - accuracy: 0.6074
# Epoch 20: val_loss did not improve from 1.21357
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.1999 - accuracy: 0.6075 - val_loss: 1.3110 - val_accuracy: 0.5759 - lr: 1.0000e-04
# Epoch 21/70
# 3500/3500 [==============================] - ETA: 0s - loss: 1.2014 - accuracy: 0.6099
# Epoch 21: val_loss did not improve from 1.21357
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.2014 - accuracy: 0.6099 - val_loss: 1.2468 - val_accuracy: 0.5990 - lr: 1.0000e-04
# Epoch 22/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 1.1883 - accuracy: 0.6149
# Epoch 22: val_loss did not improve from 1.21357
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.1882 - accuracy: 0.6149 - val_loss: 1.2264 - val_accuracy: 0.6082 - lr: 1.0000e-04
# Epoch 23/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 1.1783 - accuracy: 0.6134
# Epoch 23: val_loss did not improve from 1.21357
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.1788 - accuracy: 0.6132 - val_loss: 1.2159 - val_accuracy: 0.6056 - lr: 1.0000e-04
# Epoch 24/70
# 3500/3500 [==============================] - ETA: 0s - loss: 1.1699 - accuracy: 0.6187
# Epoch 24: val_loss improved from 1.21357 to 1.21158, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.1699 - accuracy: 0.6187 - val_loss: 1.2116 - val_accuracy: 0.6120 - lr: 1.0000e-04
# Epoch 25/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 1.1619 - accuracy: 0.6235
# Epoch 25: val_loss did not improve from 1.21158
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.1619 - accuracy: 0.6234 - val_loss: 1.2334 - val_accuracy: 0.6024 - lr: 1.0000e-04
# Epoch 26/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 1.1534 - accuracy: 0.6259
# Epoch 26: val_loss did not improve from 1.21158
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.1532 - accuracy: 0.6260 - val_loss: 1.2665 - val_accuracy: 0.5974 - lr: 1.0000e-04
# Epoch 27/70
# 3500/3500 [==============================] - ETA: 0s - loss: 1.1496 - accuracy: 0.6281
# Epoch 27: val_loss did not improve from 1.21158
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.1496 - accuracy: 0.6281 - val_loss: 1.2227 - val_accuracy: 0.6099 - lr: 1.0000e-04
# Epoch 28/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 1.1423 - accuracy: 0.6305
# Epoch 28: val_loss did not improve from 1.21158
# 3500/3500 [==============================] - 42s 12ms/step - loss: 1.1422 - accuracy: 0.6306 - val_loss: 1.2145 - val_accuracy: 0.6112 - lr: 1.0000e-04
# Epoch 29/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 1.1351 - accuracy: 0.6324
# Epoch 29: val_loss did not improve from 1.21158
# 3500/3500 [==============================] - 42s 12ms/step - loss: 1.1349 - accuracy: 0.6324 - val_loss: 1.2546 - val_accuracy: 0.6024 - lr: 1.0000e-04
# Epoch 30/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 1.1371 - accuracy: 0.6347
# Epoch 30: val_loss did not improve from 1.21158
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 3500/3500 [==============================] - 42s 12ms/step - loss: 1.1371 - accuracy: 0.6347 - val_loss: 1.3481 - val_accuracy: 0.5856 - lr: 1.0000e-04
# Epoch 31/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 1.0517 - accuracy: 0.6610
# Epoch 31: val_loss improved from 1.21158 to 1.14926, saving model to emotor.h5
# 3500/3500 [==============================] - 44s 13ms/step - loss: 1.0517 - accuracy: 0.6610 - val_loss: 1.1493 - val_accuracy: 0.6307 - lr: 2.0000e-05
# Epoch 32/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 1.0122 - accuracy: 0.6742
# Epoch 32: val_loss improved from 1.14926 to 1.14605, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 1.0122 - accuracy: 0.6742 - val_loss: 1.1460 - val_accuracy: 0.6339 - lr: 2.0000e-05
# Epoch 33/70
# 3500/3500 [==============================] - ETA: 0s - loss: 0.9899 - accuracy: 0.6791
# Epoch 33: val_loss improved from 1.14605 to 1.13039, saving model to emotor.h5
# 3500/3500 [==============================] - 42s 12ms/step - loss: 0.9899 - accuracy: 0.6791 - val_loss: 1.1304 - val_accuracy: 0.6370 - lr: 2.0000e-05
# Epoch 34/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 0.9782 - accuracy: 0.6843
# Epoch 34: val_loss did not improve from 1.13039
# 3500/3500 [==============================] - 42s 12ms/step - loss: 0.9783 - accuracy: 0.6843 - val_loss: 1.1354 - val_accuracy: 0.6368 - lr: 2.0000e-05
# Epoch 35/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.9602 - accuracy: 0.6872
# Epoch 35: val_loss improved from 1.13039 to 1.09503, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.9602 - accuracy: 0.6872 - val_loss: 1.0950 - val_accuracy: 0.6444 - lr: 2.0000e-05
# Epoch 36/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 0.9555 - accuracy: 0.6855
# Epoch 36: val_loss did not improve from 1.09503
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.9552 - accuracy: 0.6857 - val_loss: 1.1144 - val_accuracy: 0.6462 - lr: 2.0000e-05
# Epoch 37/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.9420 - accuracy: 0.6921
# Epoch 37: val_loss did not improve from 1.09503
# 3500/3500 [==============================] - 44s 12ms/step - loss: 0.9421 - accuracy: 0.6921 - val_loss: 1.1091 - val_accuracy: 0.6441 - lr: 2.0000e-05
# Epoch 38/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.9352 - accuracy: 0.6921
# Epoch 38: val_loss improved from 1.09503 to 1.09188, saving model to emotor.h5
# 3500/3500 [==============================] - 44s 13ms/step - loss: 0.9351 - accuracy: 0.6922 - val_loss: 1.0919 - val_accuracy: 0.6513 - lr: 2.0000e-05
# Epoch 39/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 0.9276 - accuracy: 0.6948
# Epoch 39: val_loss did not improve from 1.09188
# 3500/3500 [==============================] - 45s 13ms/step - loss: 0.9274 - accuracy: 0.6948 - val_loss: 1.1291 - val_accuracy: 0.6425 - lr: 2.0000e-05
# Epoch 40/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.9187 - accuracy: 0.6983
# Epoch 40: val_loss improved from 1.09188 to 1.08543, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.9186 - accuracy: 0.6983 - val_loss: 1.0854 - val_accuracy: 0.6485 - lr: 2.0000e-05
# Epoch 41/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 0.9162 - accuracy: 0.6972
# Epoch 41: val_loss improved from 1.08543 to 1.08419, saving model to emotor.h5
# 3500/3500 [==============================] - 46s 13ms/step - loss: 0.9158 - accuracy: 0.6974 - val_loss: 1.0842 - val_accuracy: 0.6495 - lr: 2.0000e-05
# Epoch 42/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 0.9077 - accuracy: 0.6999
# Epoch 42: val_loss did not improve from 1.08419
# 3500/3500 [==============================] - 44s 13ms/step - loss: 0.9077 - accuracy: 0.6999 - val_loss: 1.1104 - val_accuracy: 0.6462 - lr: 2.0000e-05
# Epoch 43/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 0.8981 - accuracy: 0.7030
# Epoch 43: val_loss did not improve from 1.08419
# 3500/3500 [==============================] - 45s 13ms/step - loss: 0.8981 - accuracy: 0.7029 - val_loss: 1.1192 - val_accuracy: 0.6463 - lr: 2.0000e-05
# Epoch 44/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 0.8951 - accuracy: 0.7056
# Epoch 44: val_loss did not improve from 1.08419
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8953 - accuracy: 0.7055 - val_loss: 1.1066 - val_accuracy: 0.6424 - lr: 2.0000e-05
# Epoch 45/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 0.8816 - accuracy: 0.7099
# Epoch 45: val_loss did not improve from 1.08419
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8816 - accuracy: 0.7099 - val_loss: 1.0873 - val_accuracy: 0.6481 - lr: 4.0000e-06
# Epoch 46/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 0.8704 - accuracy: 0.7131
# Epoch 46: val_loss did not improve from 1.08419
# 3500/3500 [==============================] - 45s 13ms/step - loss: 0.8704 - accuracy: 0.7130 - val_loss: 1.0885 - val_accuracy: 0.6510 - lr: 4.0000e-06
# Epoch 47/70
# 3500/3500 [==============================] - ETA: 0s - loss: 0.8702 - accuracy: 0.7131
# Epoch 47: val_loss did not improve from 1.08419
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8702 - accuracy: 0.7131 - val_loss: 1.0918 - val_accuracy: 0.6477 - lr: 4.0000e-06
# Epoch 48/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.8679 - accuracy: 0.7144
# Epoch 48: val_loss did not improve from 1.08419
# 3500/3500 [==============================] - 44s 12ms/step - loss: 0.8680 - accuracy: 0.7144 - val_loss: 1.0880 - val_accuracy: 0.6503 - lr: 4.0000e-06
# Epoch 49/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.8698 - accuracy: 0.7148
# Epoch 49: val_loss improved from 1.08419 to 1.08126, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8699 - accuracy: 0.7148 - val_loss: 1.0813 - val_accuracy: 0.6527 - lr: 4.0000e-06
# Epoch 50/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.8571 - accuracy: 0.7188
# Epoch 50: val_loss did not improve from 1.08126
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8570 - accuracy: 0.7189 - val_loss: 1.0851 - val_accuracy: 0.6526 - lr: 4.0000e-06
# Epoch 51/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.8631 - accuracy: 0.7145
# Epoch 51: val_loss did not improve from 1.08126
# 3500/3500 [==============================] - 42s 12ms/step - loss: 0.8632 - accuracy: 0.7145 - val_loss: 1.0856 - val_accuracy: 0.6502 - lr: 4.0000e-06
# Epoch 52/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.8638 - accuracy: 0.7160
# Epoch 52: val_loss improved from 1.08126 to 1.07303, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8636 - accuracy: 0.7161 - val_loss: 1.0730 - val_accuracy: 0.6499 - lr: 4.0000e-06
# Epoch 53/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 0.8547 - accuracy: 0.7179
# Epoch 53: val_loss did not improve from 1.07303
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8547 - accuracy: 0.7179 - val_loss: 1.0742 - val_accuracy: 0.6526 - lr: 4.0000e-06
# Epoch 54/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 0.8502 - accuracy: 0.7205
# Epoch 54: val_loss did not improve from 1.07303
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8501 - accuracy: 0.7206 - val_loss: 1.0766 - val_accuracy: 0.6520 - lr: 4.0000e-06
# Epoch 55/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.8497 - accuracy: 0.7172
# Epoch 55: val_loss did not improve from 1.07303
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8498 - accuracy: 0.7172 - val_loss: 1.0762 - val_accuracy: 0.6526 - lr: 4.0000e-06
# Epoch 56/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.8518 - accuracy: 0.7165
# Epoch 56: val_loss did not improve from 1.07303
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8517 - accuracy: 0.7165 - val_loss: 1.0772 - val_accuracy: 0.6519 - lr: 8.0000e-07
# Epoch 57/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.8491 - accuracy: 0.7207
# Epoch 57: val_loss did not improve from 1.07303
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8490 - accuracy: 0.7207 - val_loss: 1.0734 - val_accuracy: 0.6533 - lr: 8.0000e-07
# Epoch 58/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.8487 - accuracy: 0.7203
# Epoch 58: val_loss improved from 1.07303 to 1.07193, saving model to emotor.h5
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8486 - accuracy: 0.7204 - val_loss: 1.0719 - val_accuracy: 0.6536 - lr: 8.0000e-07
# Epoch 59/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 0.8469 - accuracy: 0.7205
# Epoch 59: val_loss did not improve from 1.07193
# 3500/3500 [==============================] - 44s 13ms/step - loss: 0.8469 - accuracy: 0.7205 - val_loss: 1.0723 - val_accuracy: 0.6534 - lr: 8.0000e-07
# Epoch 60/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.8479 - accuracy: 0.7184
# Epoch 60: val_loss did not improve from 1.07193
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8478 - accuracy: 0.7184 - val_loss: 1.0720 - val_accuracy: 0.6536 - lr: 8.0000e-07
# Epoch 61/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.8453 - accuracy: 0.7208
# Epoch 61: val_loss did not improve from 1.07193
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8453 - accuracy: 0.7208 - val_loss: 1.0740 - val_accuracy: 0.6531 - lr: 8.0000e-07
# Epoch 62/70
# 3500/3500 [==============================] - ETA: 0s - loss: 0.8482 - accuracy: 0.7200
# Epoch 62: val_loss did not improve from 1.07193
# 3500/3500 [==============================] - 45s 13ms/step - loss: 0.8482 - accuracy: 0.7200 - val_loss: 1.0739 - val_accuracy: 0.6531 - lr: 8.0000e-07
# Epoch 63/70
# 3499/3500 [============================>.] - ETA: 0s - loss: 0.8435 - accuracy: 0.7206
# Epoch 63: val_loss did not improve from 1.07193
# 3500/3500 [==============================] - 44s 12ms/step - loss: 0.8435 - accuracy: 0.7206 - val_loss: 1.0723 - val_accuracy: 0.6534 - lr: 8.0000e-07
# Epoch 64/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.8406 - accuracy: 0.7233
# Epoch 64: val_loss did not improve from 1.07193
# 3500/3500 [==============================] - 44s 12ms/step - loss: 0.8404 - accuracy: 0.7234 - val_loss: 1.0743 - val_accuracy: 0.6537 - lr: 8.0000e-07
# Epoch 65/70
# 3497/3500 [============================>.] - ETA: 0s - loss: 0.8440 - accuracy: 0.7212
# Epoch 65: val_loss did not improve from 1.07193
# 3500/3500 [==============================] - 43s 12ms/step - loss: 0.8440 - accuracy: 0.7213 - val_loss: 1.0754 - val_accuracy: 0.6536 - lr: 8.0000e-07
# Epoch 66/70
# 3500/3500 [==============================] - ETA: 0s - loss: 0.8428 - accuracy: 0.7229
# Epoch 66: val_loss did not improve from 1.07193
# 3500/3500 [==============================] - 45s 13ms/step - loss: 0.8428 - accuracy: 0.7229 - val_loss: 1.0730 - val_accuracy: 0.6547 - lr: 8.0000e-07
# Epoch 67/70
# 3500/3500 [==============================] - ETA: 0s - loss: 0.8417 - accuracy: 0.7219
# Epoch 67: val_loss improved from 1.07193 to 1.07189, saving model to emotor.h5
# 3500/3500 [==============================] - 45s 13ms/step - loss: 0.8417 - accuracy: 0.7219 - val_loss: 1.0719 - val_accuracy: 0.6541 - lr: 8.0000e-07
# Epoch 68/70
# 3496/3500 [============================>.] - ETA: 0s - loss: 0.8455 - accuracy: 0.7192
# Epoch 68: val_loss did not improve from 1.07189
# 3500/3500 [==============================] - 46s 13ms/step - loss: 0.8456 - accuracy: 0.7192 - val_loss: 1.0752 - val_accuracy: 0.6531 - lr: 8.0000e-07
# Epoch 69/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.8403 - accuracy: 0.7207
# Epoch 69: val_loss did not improve from 1.07189
# 3500/3500 [==============================] - 44s 13ms/step - loss: 0.8402 - accuracy: 0.7208 - val_loss: 1.0755 - val_accuracy: 0.6526 - lr: 8.0000e-07
# Epoch 70/70
# 3498/3500 [============================>.] - ETA: 0s - loss: 0.8416 - accuracy: 0.7210
# Epoch 70: val_loss did not improve from 1.07189
# 3500/3500 [==============================] - 46s 13ms/step - loss: 0.8416 - accuracy: 0.7209 - val_loss: 1.0759 - val_accuracy: 0.6515 - lr: 8.0000e-07
